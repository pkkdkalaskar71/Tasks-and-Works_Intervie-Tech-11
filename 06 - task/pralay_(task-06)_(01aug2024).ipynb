# %% [markdown]
# #### Pralay K Kalaskar
# #### (pkkdkalaskar71@gmail.com)
# #### +91-7066216365
# #### www.linkedin.com/in/pralay-kalaskar-1010
# #### Task 06 :- 01-aug-2024

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("Practice dataset 5.csv")
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
# exploration
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
# Check data types, non-null counts, and memory usage
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
# Examine summary statistics for numeric columns
df.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %%
# Check unique values in categorical columns
df['gender'].unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    58552
# Male      41430
# Other        18
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Count occurrences of each gender
gender_counts = df['gender'].value_counts()

# Plotting the bar graph
bars = plt.bar(gender_counts.index, gender_counts.values, color='lightcoral')

# Adding titles and labels
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')

# Adding numbers on top of the bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height + 0.5,  # Position the text above the bar
             f'{height}',  # The text to display
             ha='center',  # Horizontal alignment
             va='bottom')  # Vertical alignment

# Display the plot
plt.show()

# %%
df['smoking_history'].unique()
# Out:
# array(['never', 'No Info', 'current', 'former', 'ever', 'not current'],
#       dtype=object)

# %%
df['smoking_history'].value_counts()
# Out:
# smoking_history
# No Info        35816
# never          35095
# former          9352
# current         9286
# not current     6447
# ever            4004
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Count occurrences of each gender
smoking_history_counts = df['smoking_history'].value_counts()

# Plotting the bar graph
bars = plt.bar(smoking_history_counts.index, smoking_history_counts.values)

# Adding titles and labels
plt.title('smoking_history Distribution')
plt.xlabel('smoking_history')
plt.ylabel('Count')

# Adding numbers on top of the bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height + 0.5,  # Position the text above the bar
             f'{height}',  # The text to display
             ha='center',  # Horizontal alignment
             va='bottom')  # Vertical alignment

# Display the plot
plt.show()

# %%
# when you want to drop colun at that time you uncomment this and run this

## Specify the columns to drop
#columns_to_drop = ['column_name', 'column_name']

## Use the drop() method to remove the specified columns
#df = df.drop(columns=columns_to_drop)

# Display the updated DataFrame
#print(df)
