# %% [markdown]
# #### Pralay K Kalaskar
# #### (pkkdkalaskar71@gmail.com)
# #### +91-7066216365
# #### www.linkedin.com/in/pralay-kalaskar-1010
# #### Task 02 :- 23-july-2024

# %%
# Pandas is a powerful library for data manipulation and analysis.
# Importing the necessary libraries.
import pandas as pd
# "pd" This refers to the pandas library in Python.

# Replace 'your_dataset.csv' with the actual file path or URL / name of your dataset.
data = pd.read_csv('Task 2.csv')
# "data = ..." This assigns the result of pd.read_csv('your_dataset_name.csv') to the variable "data".
# The variable name "data" now holds a pandas DataFrame containing the contents of the particular CSV file.
# "read_csv()" This is a function provided by pandas to read data from a CSV file into a DataFrame. It takes the path to the CSV file as its argument.

# Displaying the first 10 rows of the dataset.
# Method 01 :-
data.head(10)
# Method 02 :-
# first_ten_rows = data.head(10)
# print(first_ten_rows)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %% [markdown]
# ## What happens after executing the commands ?
# ### (A) - Once you execute data = pd.read_csv('your_dataset_name.csv') in a Jupyter Notebook cell:
#
# ##### 1. File Reading :- pandas will locate the file 'your_dataset_name.csv' and read its contents.
# ##### 2. DataFrame Creation :- It will create a pandas DataFrame object (data) where each row of the CSV file becomes a row in the DataFrame, and each comma-separated value becomes a cell in the DataFrame.
# ##### 3. Variable Assignment :- The DataFrame data is assigned to the variable data, which means you can now refer to this DataFrame by using the variable data in subsequent code cells.
#
# ### (B) - Tips for usage:
# ##### 1) File Path :- Ensure that 'your_dataset.csv' exists in the specified location relative to where your Jupyter Notebook is running, or provide the correct path if it's in a different directory.
# ##### 2) DataFrame Operations :- After loading the data into data, you can perform various operations on it such as data cleaning, manipulation, analysis, and visualization using pandas and other Python libraries.
# ##### 3) Data Exploration :- Use data.head() to quickly inspect the first few rows of your DataFrame and data.info() to get a summary of the DataFrame structure.
