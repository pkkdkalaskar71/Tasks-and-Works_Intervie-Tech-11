# %% [markdown]
# # Exploratory Data Analysis

# %%
#load the libraries
import pandas as pd
# import numpy as np

# %%
data1 = pd.read_csv("data_clean.csv")

# %%
data1
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %% [markdown]
# # Rename the columns

# %%
data1['Temp C']
# Out:
# 0      67
# 1      72
# 2      74
# 3      62
# 4      56
#        ..
# 153    67
# 154    70
# 155    77
# 156    75
# 157    76
# Name: Temp C, Length: 158, dtype: object

# %%
# d = data1.iloc[:, 1:5]
# d.head(2)

# %%
d.Temp C
# Out:
#   Cell In[21], line 1
#     d.Temp C
#            ^
# SyntaxError: invalid syntax

# %%
data1.rename({'Solar.R': 'Solar_R','Temp C' : 'Temp_Deg'}, axis=1)

# %%
data1 = data1.rename({'Solar.R': 'Solar_R','Temp C' : 'Temp_Deg'}, axis=1)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar_R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp_Deg    158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
data1.columns

# %% [markdown]
# # Data type conversion

# %%
# data1

# %%
df = data1.copy()
df
# Out:
#      Unnamed: 0  Ozone  Solar_R  Wind Temp_Deg Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4       67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0       72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6       74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5       62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3       56     5    5  2010    56       S
# ..          ...    ...      ...   ...      ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4       67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9       70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2       77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3       75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0       76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar_R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp_Deg    158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
df.drop('Unnamed: 0',axis=1,inplace=True) # dont run second time

# %%
df
# Out:
#      Ozone  Solar_R  Wind Temp_Deg Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4       67     5    1  2010    67       S
# 1     36.0    118.0   8.0       72     5    2  2010    72       C
# 2     12.0    149.0  12.6       74     5    3  2010    74      PS
# 3     18.0    313.0  11.5       62     5    4  2010    62       S
# 4      NaN      NaN  14.3       56     5    5  2010    56       S
# ..     ...      ...   ...      ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4       67     5    1  2010    67       C
# 154   30.0    193.0   6.9       70     9   26  2010    70      PS
# 155    NaN    145.0  13.2       77     9   27  2010    77       S
# 156   14.0    191.0  14.3       75     9   28  2010    75       S
# 157   18.0    131.0   8.0       76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Ozone     120 non-null    float64
#  1   Solar_R   151 non-null    float64
#  2   Wind      158 non-null    float64
#  3   Temp_Deg  158 non-null    object
#  4   Month     158 non-null    object
#  5   Day       158 non-null    int64
#  6   Year      158 non-null    int64
#  7   Temp      158 non-null    int64
#  8   Weather   155 non-null    object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 11.2+ KB

# %%
data1
# Out:
#      Unnamed: 0  Ozone  Solar_R  Wind Temp_Deg Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4       67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0       72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6       74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5       62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3       56     5    5  2010    56       S
# ..          ...    ...      ...   ...      ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4       67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9       70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2       77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3       75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0       76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
# to remove column
data=data1.iloc[:,1:]

# %%
data
# Out:
#      Ozone  Solar_R  Wind Temp_Deg Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4       67     5    1  2010    67       S
# 1     36.0    118.0   8.0       72     5    2  2010    72       C
# 2     12.0    149.0  12.6       74     5    3  2010    74      PS
# 3     18.0    313.0  11.5       62     5    4  2010    62       S
# 4      NaN      NaN  14.3       56     5    5  2010    56       S
# ..     ...      ...   ...      ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4       67     5    1  2010    67       C
# 154   30.0    193.0   6.9       70     9   26  2010    70      PS
# 155    NaN    145.0  13.2       77     9   27  2010    77       S
# 156   14.0    191.0  14.3       75     9   28  2010    75       S
# 157   18.0    131.0   8.0       76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
dict(df.iloc[23,:])
# Out:
# {'Ozone': 32.0,
#  'Solar_R': 92.0,
#  'Wind': 12.0,
#  'Temp_Deg': '61',
#  'Month': 'May',
#  'Day': 24,
#  'Year': 2010,
#  'Temp': 61,
#  'Weather': 'C'}

# %%
data['Month']
# Out:
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
#       ..
# 153    5
# 154    9
# 155    9
# 156    9
# 157    9
# Name: Month, Length: 158, dtype: object

# %%
pd.to_numeric(data['Month'],errors='coerce').astype('int64') # error because of Nan value
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 pd.to_numeric(data['Month'],errors='coerce').astype('int64') # error because of Nan value
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
pd.to_numeric(data['Month'],errors='coerce') # nan value present with dtype float
# Out:
# 0      5.0
# 1      5.0
# 2      5.0
# 3      5.0
# 4      5.0
#       ...
# 153    5.0
# 154    9.0
# 155    9.0
# 156    9.0
# 157    9.0
# Name: Month, Length: 158, dtype: float64

# %%
pd.to_numeric(data['Month'],errors='coerce').dropna() # nan value removed

# %%
pd.to_numeric(data['Month'],errors='coerce').dropna().astype('int64') # converted dtype from float to int

# %%
data['Month']=pd.to_numeric(data['Month'],errors='coerce')
data['Temp_Deg']=pd.to_numeric(data['Temp_Deg'],errors='coerce') # coerce will introduce NA values for non numeric data in the columns
data['Weather']=data['Weather'].astype('category')

# %%
# data['Ozone']=data['Ozone'].astype('float64')
#data['Wind']=data['Wind'].astype('int64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Ozone     120 non-null    float64
#  1   Solar_R   151 non-null    float64
#  2   Wind      158 non-null    float64
#  3   Temp_Deg  157 non-null    float64
#  4   Month     157 non-null    float64
#  5   Day       158 non-null    int64
#  6   Year      158 non-null    int64
#  7   Temp      158 non-null    int64
#  8   Weather   155 non-null    category
# dtypes: category(1), float64(5), int64(3)
# memory usage: 10.3 KB

# %%
df.head(60)
# Out:
#     Ozone  Solar_R  Wind Temp_Deg Month  Day  Year  Temp Weather
# 0    41.0    190.0   7.4       67     5    1  2010    67       S
# 1    36.0    118.0   8.0       72     5    2  2010    72       C
# 2    12.0    149.0  12.6       74     5    3  2010    74      PS
# 3    18.0    313.0  11.5       62     5    4  2010    62       S
# 4     NaN      NaN  14.3       56     5    5  2010    56       S
# 5    28.0      NaN  14.9       66     5    6  2010    66       C
# 6    23.0    299.0   8.6       65     5    7  2010    65      PS
# 7    19.0     99.0  13.8       59     5    8  2010    59       C
# 8     8.0     19.0  20.1       61     5    9  2010    61      PS
# 9     NaN    194.0   8.6       69     5   10  2010    69       S
# 10    7.0      NaN   6.9        C     5   11  2010    74       C
# 11   16.0    256.0   9.7       69     5   12  2010    69      PS
# 12   11.0    290.0   9.2       66     5   13  2010    66       S
# ...

# %%
dict(data.iloc[10,:])
# Out:
# {'Ozone': 7.0,
#  'Solar_R': nan,
#  'Wind': 6.9,
#  'Temp_Deg': nan,
#  'Month': 5.0,
#  'Day': 11,
#  'Year': 2010,
#  'Temp': 74,
#  'Weather': 'C'}

# %%
data
# Out:
#      Ozone  Solar_R  Wind  Temp_Deg  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4      67.0    5.0    1  2010    67       S
# 1     36.0    118.0   8.0      72.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6      74.0    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5      62.0    5.0    4  2010    62       S
# 4      NaN      NaN  14.3      56.0    5.0    5  2010    56       S
# ..     ...      ...   ...       ...    ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4      67.0    5.0    1  2010    67       C
# 154   30.0    193.0   6.9      70.0    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2      77.0    9.0   27  2010    77       S
# 156   14.0    191.0  14.3      75.0    9.0   28  2010    75       S
# 157   18.0    131.0   8.0      76.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %% [markdown]
# # Duplicates

# %%
data[data.duplicated()]
# Out:
#      Ozone  Solar_R  Wind  Temp_Deg  Month  Day  Year  Temp Weather
# 156   14.0    191.0  14.3      75.0    9.0   28  2010    75       S

# %%
df.tail(8)
# Out:
#      Ozone  Solar_R  Wind Temp_Deg Month  Day  Year  Temp Weather
# 150   14.0    191.0  14.3       75     9   28  2010    75       S
# 151   18.0    131.0   8.0       76     9   29  2010    76      PS
# 152   20.0    223.0  11.5       68     9   30  2010    68       S
# 153   41.0    190.0   7.4       67     5    1  2010    67       C
# 154   30.0    193.0   6.9       70     9   26  2010    70      PS
# 155    NaN    145.0  13.2       77     9   27  2010    77       S
# 156   14.0    191.0  14.3       75     9   28  2010    75       S
# 157   18.0    131.0   8.0       76     9   29  2010    76       C

# %%
dict(data.iloc[150,:])
# Out:
# {'Ozone': 14.0,
#  'Solar_R': 191.0,
#  'Wind': 14.3,
#  'Temp_Deg': 75.0,
#  'Month': 9.0,
#  'Day': 28,
#  'Year': 2010,
#  'Temp': 75,
#  'Weather': 'S'}

# %%
#Count of duplicated rows
data[data.duplicated()]

# %%
data_cleaned1=data.drop_duplicates()

# %%
data_cleaned1[data_cleaned1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Ozone, Solar_R, Wind, Temp_Deg, Month, Day, Year, Temp, Weather]
# Index: []

# %%
data_cleaned1
# Out:
#      Ozone  Solar_R  Wind  Temp_Deg  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4      67.0    5.0    1  2010    67       S
# 1     36.0    118.0   8.0      72.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6      74.0    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5      62.0    5.0    4  2010    62       S
# 4      NaN      NaN  14.3      56.0    5.0    5  2010    56       S
# ..     ...      ...   ...       ...    ...  ...   ...   ...     ...
# 152   20.0    223.0  11.5      68.0    9.0   30  2010    68       S
# 153   41.0    190.0   7.4      67.0    5.0    1  2010    67       C
# 154   30.0    193.0   6.9      70.0    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2      77.0    9.0   27  2010    77       S
# 157   18.0    131.0   8.0      76.0    9.0   29  2010    76       C
#
# [157 rows x 9 columns]

# %% [markdown]
# # Drop columns

# %%
data_cleaned1
# Out:
#      Ozone  Solar_R  Wind  Temp_Deg  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4      67.0    5.0    1  2010    67       S
# 1     36.0    118.0   8.0      72.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6      74.0    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5      62.0    5.0    4  2010    62       S
# 4      NaN      NaN  14.3      56.0    5.0    5  2010    56       S
# ..     ...      ...   ...       ...    ...  ...   ...   ...     ...
# 152   20.0    223.0  11.5      68.0    9.0   30  2010    68       S
# 153   41.0    190.0   7.4      67.0    5.0    1  2010    67       C
# 154   30.0    193.0   6.9      70.0    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2      77.0    9.0   27  2010    77       S
# 157   18.0    131.0   8.0      76.0    9.0   29  2010    76       C
#
# [157 rows x 9 columns]

# %%
data_cleaned2=data_cleaned1.drop('Temp_Deg',axis=1)

# %%
data_cleaned2
# Out:
#      Ozone  Solar_R  Wind  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    5.0    4  2010    62       S
# 4      NaN      NaN  14.3    5.0    5  2010    56       S
# ..     ...      ...   ...    ...  ...   ...   ...     ...
# 152   20.0    223.0  11.5    9.0   30  2010    68       S
# 153   41.0    190.0   7.4    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    9.0   27  2010    77       S
# 157   18.0    131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %% [markdown]
# # Outlier Detection

# %%
# histogram of Ozone
data_cleaned2['Ozone'].hist()
# Out:
# <Axes: >

# %%
#Box plot
data_cleaned2.boxplot(column=['Ozone'])
# Out:
# <Axes: >

# %%
data_cleaned2.describe()
# Out:
#             Ozone     Solar_R        Wind       Month         Day    Year  \
# count  119.000000  150.000000  157.000000  156.000000  157.000000   157.0
# mean    41.815126  185.366667    9.929936    7.032051   15.929936  2010.0
# std     32.659249   89.019146    3.505188    1.429730    8.974404     0.0
# min      1.000000    7.000000    1.700000    5.000000    1.000000  2010.0
# 25%     18.000000  118.500000    7.400000    6.000000    8.000000  2010.0
# 50%     31.000000  199.000000    9.700000    7.000000   16.000000  2010.0
# 75%     62.000000  257.500000   11.500000    8.000000   24.000000  2010.0
# max    168.000000  334.000000   20.700000    9.000000   31.000000  2010.0
#
#              Temp
# count  157.000000
# mean    77.745223
# std      9.405334
# min     56.000000
# 25%     72.000000
# 50%     79.000000
# 75%     84.000000
# max     97.000000

# %%
data_cleaned2[data_cleaned2['Ozone']<125].describe()
# Out:
#             Ozone     Solar_R        Wind       Month         Day    Year  \
# count  117.000000  112.000000  117.000000  116.000000  117.000000   117.0
# mean    39.940171  183.214286    9.904274    7.224138   15.658120  2010.0
# std     29.484739   90.382015    3.489872    1.492510    8.810419     0.0
# min      1.000000    7.000000    2.300000    5.000000    1.000000  2010.0
# 25%     18.000000  114.250000    7.400000    6.000000    8.000000  2010.0
# 50%     30.000000  199.000000    9.700000    7.000000   16.000000  2010.0
# 75%     59.000000  254.250000   11.500000    9.000000   22.000000  2010.0
# max    122.000000  334.000000   20.700000    9.000000   31.000000  2010.0
#
#              Temp
# count  117.000000
# mean    77.615385
# std      9.503036
# min     57.000000
# 25%     71.000000
# 50%     78.000000
# 75%     85.000000
# max     97.000000

# %%
#Bar plot
data['Weather'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Weather'>

# %%
data['Weather'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
data_cleaned2.corr(numeric_only=True)
# Out:
#             Ozone   Solar_R      Wind     Month       Day  Year      Temp
# Ozone    1.000000  0.350274 -0.590270  0.147231 -0.025465   NaN  0.694404
# Solar_R  0.350274  1.000000 -0.057407 -0.094012 -0.155663   NaN  0.273558
# Wind    -0.590270 -0.057407  1.000000 -0.166216  0.029900   NaN -0.441228
# Month    0.147231 -0.094012 -0.166216  1.000000  0.050055   NaN  0.398516
# Day     -0.025465 -0.155663  0.029900  0.050055  1.000000   NaN -0.122787
# Year          NaN       NaN       NaN       NaN       NaN   NaN       NaN
# Temp     0.694404  0.273558 -0.441228  0.398516 -0.122787   NaN  1.000000

# %%
dfg = data_cleaned2.copy()
dfg.head()
# Out:
#    Ozone  Solar_R  Wind  Month  Day  Year  Temp Weather
# 0   41.0    190.0   7.4    5.0    1  2010    67       S
# 1   36.0    118.0   8.0    5.0    2  2010    72       C
# 2   12.0    149.0  12.6    5.0    3  2010    74      PS
# 3   18.0    313.0  11.5    5.0    4  2010    62       S
# 4    NaN      NaN  14.3    5.0    5  2010    56       S

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dfg['Weather']=le.fit_transform(dfg['Weather'])

# %%
dfg
# Out:
#      Ozone  Solar_R  Wind  Month  Day  Year  Temp  Weather
# 0     41.0    190.0   7.4    5.0    1  2010    67        2
# 1     36.0    118.0   8.0    5.0    2  2010    72        0
# 2     12.0    149.0  12.6    5.0    3  2010    74        1
# 3     18.0    313.0  11.5    5.0    4  2010    62        2
# 4      NaN      NaN  14.3    5.0    5  2010    56        2
# ..     ...      ...   ...    ...  ...   ...   ...      ...
# 152   20.0    223.0  11.5    9.0   30  2010    68        2
# 153   41.0    190.0   7.4    5.0    1  2010    67        0
# 154   30.0    193.0   6.9    9.0   26  2010    70        1
# 155    NaN    145.0  13.2    9.0   27  2010    77        2
# 157   18.0    131.0   8.0    9.0   29  2010    76        0
#
# [157 rows x 8 columns]

# %%
dfg.corr()['Weather']
# Out:
# Ozone     -0.095191
# Solar_R   -0.035674
# Wind       0.038448
# Month      0.028578
# Day        0.018966
# Year            NaN
# Temp       0.048536
# Weather    1.000000
# Name: Weather, dtype: float64

# %% [markdown]
# # Missing Values and Imputation

# %%
data_cleaned3.columns

# %%
import seaborn as sns
sns.heatmap(data_cleaned3.corr(),annot=True)

# %%
data_cleaned3.columns

# %%
data_cleaned3.isnull()

# %%
import seaborn as sns
cols = data_cleaned3.columns 
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(data_cleaned3[cols].isnull(),
            cmap=sns.color_palette(colours))

# %%
data_cleaned3.isnull().sum()

# %%
data_cleaned3[data_cleaned3.isnull().any(axis=1)]

# %%
data_cleaned3.describe()

# %%
#Mean Imputation
mean = data_cleaned3['Ozone'].mean()
print(mean)

# %%
data_cleaned3['Ozone'] = data_cleaned3['Ozone'].fillna(mean)

# %%
data_cleaned3.describe()

# %%
data_cleaned3.isnull().sum()

# %%
#Missing value imputation for categorical vlaue
#Get the object columns
obj_columns=data_cleaned3[['Weather']]
obj_columns.value_counts()

# %%
obj_columns.isnull().sum()

# %%
#Missing value imputation for categorical vlaue
obj_columns=obj_columns.fillna(obj_columns.mode().iloc[0])
obj_columns

# %%
# data_cleaned3['Weather']=data_cleaned3['Weather'].fillna(obj_columns.mode().iloc[0])
# data_cleaned3

# %%
obj_columns.isnull().sum()

# %%
data_cleaned3.shape

# %%
obj_columns.shape

# %%
#Join the data set with imputed object dataset
data_cleaned4=pd.concat([data_cleaned3,obj_columns],axis=1)
data_cleaned4

# %%
data_cleaned4.isnull().sum()

# %% [markdown]
# # Scatter plot and Correlation analysis

# %%
# Seaborn visualization library
import seaborn as sns
# Create the default pairplot
sns.pairplot(data_cleaned3)

# %%
#Correlation
data_cleaned3.corr()

# %% [markdown]
# # Transformations

# %% [markdown]
# #### Dummy Variable

# %%
data

# %%
#Creating dummy variable for Weather column
data_cleaned4=pd.get_dummies(data,columns=['Weather'])

# %%
data_cleaned4

# %%
data_cleaned4.describe()

# %%
data_cleaned4=data_cleaned4.dropna()

# %%
data_cleaned4.shape

# %% [markdown]
# #### Normalization of the data

# %%
#Normalization of the data
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

# %%
data_cleaned4

# %%
data_cleaned4.values # will conevrt into array

# %%
array[:,0:5]

# %%
array = data_cleaned3.values

scaler = MinMaxScaler(feature_range=(0,1))
rescaledX = scaler.fit_transform(array[:,0:5])

# #transformed data
set_printoptions(precision=3)
# print(rescaledX[0:5,:])
rescaledX

# %%
# Standardize data (0 mean, 1 stdev)
from sklearn.preprocessing import StandardScaler

# %%
array = data_cleaned4.values
scaler = StandardScaler().fit(array)
rescaledX = scaler.transform(array)
# rescaledX
# summarize transformed data
set_printoptions(precision=2)
print(rescaledX[0:5,:])

# %%
# python learn basic
# ml library (numpy,pandas along with stats)
# ml library visulization through stats and matplotlib and seaborn

# in between descriptive analytics (through pandas) and inferntial analytics
# hypothesis 
# normal distribution
# anova 
# chi

# EDA

# %%
# pip install pandas-profiling

# %%
# pip install pandas_profiling

# %%
# pip install sweetviz

# %%
import pandas_profiling as pp

# %%
data.shape

# %%
9*158

# %%
1422  100
50     ?

# %%
5000/1422

# %% [markdown]
# # Speed up the EDA process

# %%
EDA_report = pp.ProfileReport(data)
EDA_report.to_file(output_file='report.html')

# %%
# import sweetviz as sv

# %%
import numpy as np
import warnings
np.warnings = warnings

# %%
# sweet_report = sv.analyze(data)
# sweet_report.show_html('weather_report.html')
